# %%
import os
import requests
from bs4 import BeautifulSoup
import zipfile
import io

# %%
# ✅ Definir corretamente o diretório base dentro do seu workspace
PASTA_BASE = "/home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos"

# Criar o diretório base se não existir
os.makedirs(PASTA_BASE, exist_ok=True)

# Definir permissões para garantir acesso
os.chmod(PASTA_BASE, 0o755)

# URL principal dos dados
BASE_URL = "https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/"

# %%
# 1️⃣ BAIXAR A PÁGINA PRINCIPAL E EXTRAIR OS DIRETÓRIOS
print("🔄 Obtendo a lista de diretórios...")
response = requests.get(BASE_URL)
soup = BeautifulSoup(response.text, "html.parser")

# Encontrar todos os links que correspondem a diretórios (exemplo: "2025-02/")
pastas = [a['href'] for a in soup.find_all("a", href=True) if a['href'].endswith("/") and a['href'] != "../"]
print(f"📁 Diretórios encontrados: {pastas}")
# Out:
# 🔄 Obtendo a lista de diretórios...
# 📁 Diretórios encontrados: ['/dados/cnpj/', '2023-05/', '2023-06/', '2023-07/', '2023-08/', '2023-09/', '2023-10/', '2023-11/', '2023-12/', '2024-01/', '2024-02/', '2024-03/', '2024-04/', '2024-05/', '2024-06/', '2024-07/', '2024-08/', '2024-09/', '2024-10/', '2024-11/', '2024-12/', '2025-01/', '2025-02/', 'temp/']

# %%
# 2️⃣ ITERAR SOBRE CADA DIRETÓRIO PARA BAIXAR OS ARQUIVOS ZIP
for pasta in pastas:
    url_pasta = BASE_URL + pasta
    response_pasta = requests.get(url_pasta)
    soup_pasta = BeautifulSoup(response_pasta.text, "html.parser")

    # ✅ Criar a estrutura correta dentro de `arquivos/dados/`
    caminho_pasta_local = os.path.join(PASTA_BASE, "dados", pasta.strip('/'))
    print(f'📂 Criando pasta: {caminho_pasta_local}')
    
    os.makedirs(caminho_pasta_local, exist_ok=True)

    # Definir permissões na pasta criada
    os.chmod(caminho_pasta_local, 0o755)

    # 3️⃣ LISTAR ARQUIVOS ZIP DENTRO DO DIRETÓRIO
    arquivos_zip = [a['href'] for a in soup_pasta.find_all("a", href=True) if a['href'].endswith(".zip")]
    print(f"📂 {pasta} - Arquivos ZIP encontrados: {arquivos_zip}")

    for arquivo_zip in arquivos_zip:
        url_arquivo = url_pasta + arquivo_zip
        caminho_arquivo_zip = os.path.join(caminho_pasta_local, arquivo_zip)

        # 4️⃣ FAZER DOWNLOAD DO ARQUIVO ZIP SE ELE NÃO EXISTIR
        if not os.path.exists(caminho_arquivo_zip):
            print(f"⬇️ Baixando {url_arquivo}...")
            response_zip = requests.get(url_arquivo, stream=True)

            if response_zip.status_code == 200:
                with open(caminho_arquivo_zip, "wb") as f:
                    f.write(response_zip.content)
                print(f"✅ Download concluído: {caminho_arquivo_zip}")
            else:
                print(f"❌ Erro ao baixar {url_arquivo}")

        # 5️⃣ EXTRAIR O CONTEÚDO DO ZIP NA MESMA ESTRUTURA
        with zipfile.ZipFile(caminho_arquivo_zip, "r") as zip_ref:
            zip_ref.extractall(caminho_pasta_local)
            print(f"📂 Arquivo extraído em: {caminho_pasta_local}")

print("✅ Processo concluído! Todos os arquivos foram baixados e extraídos.")
# Out:
# 📂 Criando pasta: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/dados/cnpj
# 📂 /dados/cnpj/ - Arquivos ZIP encontrados: []
# 📂 Criando pasta: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# 📂 2023-05/ - Arquivos ZIP encontrados: ['Cnaes.zip', 'Empresas0.zip', 'Empresas1.zip', 'Empresas2.zip', 'Empresas3.zip', 'Empresas4.zip', 'Empresas5.zip', 'Empresas6.zip', 'Empresas7.zip', 'Empresas8.zip', 'Empresas9.zip', 'Estabelecimentos0.zip', 'Estabelecimentos1.zip', 'Estabelecimentos2.zip', 'Estabelecimentos3.zip', 'Estabelecimentos4.zip', 'Estabelecimentos5.zip', 'Estabelecimentos6.zip', 'Estabelecimentos7.zip', 'Estabelecimentos8.zip', 'Estabelecimentos9.zip', 'Motivos.zip', 'Municipios.zip', 'Naturezas.zip', 'Paises.zip', 'Qualificacoes.zip', 'Simples.zip', 'Socios0.zip', 'Socios1.zip', 'Socios2.zip', 'Socios3.zip', 'Socios4.zip', 'Socios5.zip', 'Socios6.zip', 'Socios7.zip', 'Socios8.zip', 'Socios9.zip']
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Cnaes.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Cnaes.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas0.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas0.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas1.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas1.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas2.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas2.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas3.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas3.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas4.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas4.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas5.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas5.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas6.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas6.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas7.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas7.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas8.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas8.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Empresas9.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Empresas9.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos0.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos0.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos1.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos1.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos2.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos2.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos3.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos3.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos4.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos4.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos5.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos5.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos6.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos6.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos7.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos7.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos8.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos8.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Estabelecimentos9.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Estabelecimentos9.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Motivos.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Motivos.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Municipios.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Municipios.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Naturezas.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Naturezas.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Paises.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Paises.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Qualificacoes.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Qualificacoes.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Simples.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Simples.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios0.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios0.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios1.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios1.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios2.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios2.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios3.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios3.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios4.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios4.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios5.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios5.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios6.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios6.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios7.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios7.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios8.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios8.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-05/Socios9.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05/Socios9.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-05
# 📂 Criando pasta: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# 📂 2023-06/ - Arquivos ZIP encontrados: ['Cnaes.zip', 'Empresas0.zip', 'Empresas1.zip', 'Empresas2.zip', 'Empresas3.zip', 'Empresas4.zip', 'Empresas5.zip', 'Empresas6.zip', 'Empresas7.zip', 'Empresas8.zip', 'Empresas9.zip', 'Estabelecimentos0.zip', 'Estabelecimentos1.zip', 'Estabelecimentos2.zip', 'Estabelecimentos3.zip', 'Estabelecimentos4.zip', 'Estabelecimentos5.zip', 'Estabelecimentos6.zip', 'Estabelecimentos7.zip', 'Estabelecimentos8.zip', 'Estabelecimentos9.zip', 'Motivos.zip', 'Municipios.zip', 'Naturezas.zip', 'Paises.zip', 'Qualificacoes.zip', 'Simples.zip', 'Socios0.zip', 'Socios1.zip', 'Socios2.zip', 'Socios3.zip', 'Socios4.zip', 'Socios5.zip', 'Socios6.zip', 'Socios7.zip', 'Socios8.zip', 'Socios9.zip']
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Cnaes.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Cnaes.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas0.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas0.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas1.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas1.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas2.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas2.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas3.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas3.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas4.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas4.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas5.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas5.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas6.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas6.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas7.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas7.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas8.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas8.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Empresas9.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Empresas9.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos0.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos0.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos1.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos1.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos2.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos2.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos3.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos3.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos4.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos4.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos5.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos5.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos6.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos6.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos7.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos7.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos8.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos8.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Estabelecimentos9.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Estabelecimentos9.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Motivos.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Motivos.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Municipios.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Municipios.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Naturezas.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Naturezas.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Paises.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Paises.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Qualificacoes.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Qualificacoes.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Simples.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Simples.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios0.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios0.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios1.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios1.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios2.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios2.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios3.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios3.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios4.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios4.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios5.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios5.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios6.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios6.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios7.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios7.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios8.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios8.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-06/Socios9.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06/Socios9.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-06
# 📂 Criando pasta: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# 📂 2023-07/ - Arquivos ZIP encontrados: ['Cnaes.zip', 'Empresas0.zip', 'Empresas1.zip', 'Empresas2.zip', 'Empresas3.zip', 'Empresas4.zip', 'Empresas5.zip', 'Empresas6.zip', 'Empresas7.zip', 'Empresas8.zip', 'Empresas9.zip', 'Estabelecimentos0.zip', 'Estabelecimentos1.zip', 'Estabelecimentos2.zip', 'Estabelecimentos3.zip', 'Estabelecimentos4.zip', 'Estabelecimentos5.zip', 'Estabelecimentos6.zip', 'Estabelecimentos7.zip', 'Estabelecimentos8.zip', 'Estabelecimentos9.zip', 'Motivos.zip', 'Municipios.zip', 'Naturezas.zip', 'Paises.zip', 'Qualificacoes.zip', 'Simples.zip', 'Socios0.zip', 'Socios1.zip', 'Socios2.zip', 'Socios3.zip', 'Socios4.zip', 'Socios5.zip', 'Socios6.zip', 'Socios7.zip', 'Socios8.zip', 'Socios9.zip']
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Cnaes.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Cnaes.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas0.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas0.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas1.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas1.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas2.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas2.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas3.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas3.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas4.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas4.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas5.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas5.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas6.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas6.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas7.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas7.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas8.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas8.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Empresas9.zip...
# ✅ Download concluído: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07/Empresas9.zip
# 📂 Arquivo extraído em: /home/danielbarbosa/seget/notebooks/dados_abertos_cnpj/arquivos/dados/2023-07
# ⬇️ Baixando https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj/2023-07/Estabelecimentos0.zip...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
